# %% [markdown]
# # Importing all neccessary modules

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.image as mpimg
import scipy.stats as stats

# %% [markdown]
# # Importing the clean Boston_DataFrame
# # Printing all statistics and counts for every column

# %%
Boston_DataFrame = pd.read_csv(open('Clean Boston Data.csv'), index_col = 0)
print(type(Boston_DataFrame))
print(Boston_DataFrame.head())
print(Boston_DataFrame.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# ...

# %% [markdown]
# # Importing all boxplots and count histograms for each column

# %% [markdown]
# ## Measurement of crime per capita

# %%
plt.imshow(mpimg.imread('CRIM_Series_visual_info.png'))

# %% [markdown]
# ### Observations And Comments
#
# ##### The distribution of the histogram clearly shows an exponential decay in frequency as the crime per capita increases.
# ##### The frequency distribution is clearly very dense between values 0 to 3, but interestingly, there are a small group of subhurbs that appear to be positive outliers where crime rate is higher.  These outliers were included so that any manipulating variable that may cause significant deviation.  For example, it will be observed that these subhurbs with higher crime rates are the same subhurbs that have a certain PTRATIO, TAX and RAD as seen from the increasing number of crime rates when the PTRATIO, TAX and RAD are all fixed values within the joint plots below.

# %% [markdown]
# ### CRIM_Series questions so far:
#
# ##### Why is the distribution so steep as the crime per capita tends to the minimum value?
# ##### What is the causes of the high deviation of the top 25% of values?
# ##### why is the maximum value so high?
# ##### Are these subhurbs with higher crime rates close together in proximity?

# %% [markdown]
# ## Proportion of residential land zoned for lots over 25000 sq feet

# %%
plt.imshow(mpimg.imread('ZN_Series_visual_info.png'))
print(Boston_DataFrame['ZN'].describe())
# Out:
# count    506.000000
# mean      11.363636
# std       23.322453
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       12.500000
# max      100.000000
# Name: ZN, dtype: float64

# %% [markdown]
# ###  Comments And Observations
# ##### The vase majority of subhurbs have no residential land zoned for plots over 25000 square feet.
# ##### There's a binary distribution between 0 and around 12%.
# ##### There is a high variation from 12 to 100.

# %% [markdown]
# ### ZN_Series questions so far
# #### Why is there a high variation between 0 and 100%
# #### Is there any congruent relationship between varied distributions for the top 25% of datapoints
# #### between the crime per capita and the proportion of residential land zoned for lots over 25000 square feet?
# #### Why is there a binary distribution between the interquartile range?
# #### Why are there so many subhurbs that have no residential land zoned for lots of 25000 square feet?

# %% [markdown]
# ## Proportion of non-retail business acres per subhurb

# %%
plt.imshow(mpimg.imread('INDUS_Series_visual_info.png'))
print(Boston_DataFrame['INDUS'].describe())
# Out:
# count    506.000000
# mean      11.136779
# std        6.860353
# min        0.460000
# 25%        5.190000
# 50%        9.690000
# 75%       18.100000
# max       27.740000
# Name: INDUS, dtype: float64

# %% [markdown]
# ### Observations and Comments
# ##### There is high number of subhurbs that are situated on and very near to the top border of the
# ##### interquartile range.
# ##### There is a stratified distribution among the top 25% of datapoints.

# %% [markdown]
# ### INDUS_Series questons so far
# ##### Why are the majority of the datapoints below 10?
# ##### Why is there a stratified distribution among the top 25% of datapoints?  Are there any causes to
# ##### this and what are they?
# ##### Are there any obvious relationships between this attribute and the other attributes?

# %% [markdown]
# ### CHAS Factor: 1 if tract borders Charle's River and 0 otherwise

# %%
plt.imshow(mpimg.imread('CHAS_Series_visual_info.png'))
print(Boston_DataFrame['CHAS'].describe())
# Out:
# count    506.000000
# mean       0.069170
# std        0.253994
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: CHAS, dtype: float64

# %% [markdown]
# ### Observations And Comments
# ##### There is clearly an absolute binary distribution between 0 and 1 indicating that this is a categorical variable.
# ##### The subhurb either runs through a river or it doesn't.
# ##### There a far more 0' s that 1's

# %% [markdown]
# ### CHAS_Series questions so far
# ##### Are there any strong congruent relationship between this attribute and any others?
# ##### Note: Includine this attribute as hue = 'CHAS' might answer the above question

# %% [markdown]
# ## Nitric Oxide gas concentrations in the air (in parts per 10 billion)

# %%
plt.imshow(mpimg.imread('NOX_Series_visual_info.png'))
print(Boston_DataFrame['NOX'].describe())
# Out:
# count    506.000000
# mean       0.554695
# std        0.115878
# min        0.385000
# 25%        0.449000
# 50%        0.538000
# 75%        0.624000
# max        0.871000
# Name: NOX, dtype: float64

# %% [markdown]
# ### Observations And Comments
# ##### There is an even distribution of NOX concentration values.
# ##### Some subhurbs have higher concentrations than others.
# ##### No obvious systematic distribution.

# %% [markdown]
# ### NOX_Series questions so far
#
# ##### Are there any relationships or associations between this attribute and the others?
# ##### Are there any causes to the NOX content in the air such as factories, coal plants or other pollutants within those subhurbs?
# ##### How closely does this variable correlate to the INDUS measurement?
# ##### If there are causes that relate to the NOX content, are these causes affecting the other attributes?

# %% [markdown]
# ## Average number of rooms per house/dwelling

# %%
plt.imshow(mpimg.imread('RM_Series_visual_info.png'))
print(Boston_DataFrame['RM'].describe())
# Out:
# count    506.000000
# mean       6.284634
# std        0.702617
# min        3.561000
# 25%        5.885500
# 50%        6.208500
# 75%        6.623500
# max        8.780000
# Name: RM, dtype: float64

# %% [markdown]
# ### Observations And Comments
# #### A symmetrical gaussian distribution.
# #### A distribution count like this means that this is a completely independent variable.

# %% [markdown]
# ### RM_Series questons so far
# ##### Is there any relationships between this attribute and any others?

# %% [markdown]
# ## Proportion of houses that were built before 1940

# %%
plt.imshow(mpimg.imread('AGE_Series_visual_info.png'))
print(Boston_DataFrame['AGE'].describe())
# Out:
# count    506.000000
# mean      68.574901
# std       28.148861
# min        2.900000
# 25%       45.025000
# 50%       77.500000
# 75%       94.075000
# max      100.000000
# Name: AGE, dtype: float64

# %% [markdown]
# ### Comments And Observations
# ##### There is an exponential growth between the values and the frequency.
# ##### The distribution of the bottom 75% of datapoints do not follow an exponential growth curve.  Instead there is a wide deviation of datapoints between 3 houses and 80.
# ##### This suggests that there are quite a few subhurbs where there has been lots of new growth and construction and lots of houses within a concentrated area where there has been little or no construction or growth i.e. downtown.

# %% [markdown]
# ### AGE_Series questions so far
# ##### What's causing the exponential growth of datapoints within the top 25%?
# #### Does this attribute associated and determine the datapoints of the other variables?
# #### Is there any relationship between the distribution within the interquartile range and the attributes?

# %%
plt.imshow(mpimg.imread('DIS_Series_visual_info.png'))
print(Boston_DataFrame['DIS'].describe())
# Out:
# count    506.000000
# mean       3.795043
# std        2.105710
# min        1.129600
# 25%        2.100175
# 50%        3.207450
# 75%        5.188425
# max       12.126500
# Name: DIS, dtype: float64

# %% [markdown]
# ### Comments and Observations
# ##### There is an exponential decay between the frequency of subhurbs and their respective employment centers.

# %% [markdown]
# ### DIS_Series questons so far
# ##### What's causing the exponential decay?
# ##### Is there a close relationship between this attribute and the AGE measurement?
# ##### Do subhurbs with more older homes also have close proximity to employment centers?

# %% [markdown]
# ## Index of accessability to radial highways per subhurb

# %%
plt.imshow(mpimg.imread('RAD_Series_visual_info.png'))
print(Boston_DataFrame['RAD'].describe())
# Out:
# count    506.000000
# mean       9.549407
# std        8.707259
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%       24.000000
# max       24.000000
# Name: RAD, dtype: float64

# %% [markdown]
# ## Comments And Observations
# ##### The distribution of subhurbs that have access to radial highways are discrete.
# ##### The vast majority of the values are on the lower scale of the interquartile range.  There are no values from 8 to 23.
# ##### The highest count in the number of subhurbs that are close in proximity to radial highways is 23.

# %% [markdown]
# ### RAD_Series questions so far
# ##### Why are the subhurb counts discretely distributed?

# %% [markdown]
# ## Full property tax rate per USD $10 000

# %%
plt.imshow(mpimg.imread('TAX_Series_visual_info.png'))
print(Boston_DataFrame['TAX'].describe())
# Out:
# count    506.000000
# mean     408.237154
# std      168.537116
# min      187.000000
# 25%      279.000000
# 50%      330.000000
# 75%      666.000000
# max      711.000000
# Name: TAX, dtype: float64

# %% [markdown]
# ### Comments And Observations
# #### There are a dense population of subhurbs that have very high property tax.
# #### The bottom 75% of datapoints partially resemble a normal distribution.

# %% [markdown]
# ### TAX_Series questions so far
# ##### Why are there a discrete population of subhurbs with very high property tax?

# %% [markdown]
# ## Pupil - Teacher Ratio

# %%
plt.imshow(mpimg.imread('PTRATIO_Series_visual_info.png'))
print(Boston_DataFrame['PTRATIO'].describe())
# Out:
# count    506.000000
# mean      18.455534
# std        2.164946
# min       12.600000
# 25%       17.400000
# 50%       19.050000
# 75%       20.200000
# max       22.000000
# Name: PTRATIO, dtype: float64

# %% [markdown]
# ### Comments And Observations
# ##### Except for a large spike in the amount of subhurbs where the PTRATIO is around 22, the distribution is fairly even with a certain number of subhurbs spiking at higher values.
# ##### There's a large spike in the distribution where the PTRATIO is around 22.

# %% [markdown]
# ### PTRATIO_Series questions so far
# ##### Why the large spike in the number of subhurb counts where the PTRATIO is around 22?

# %% [markdown]
# ## B Factor: Calculated as 1000*(Bk - 0.63) Where Bk is the proportion of black people

# %%
plt.imshow(mpimg.imread('B_Series_visual_info.png'))

# %% [markdown]
# ### Comments And Observations
# ##### The bottom 25 percentile for this attribute is 375.  According to the formula, the B factor can only be this high or higher if the proportion of black people is less than 2%.  Therefore the vast majority of subhurbs have less than 2% black people.
# ##### The remaining distribution of subhurbs where the B value is close to 0 means that the proportion of black people has to be close to 63% as possible.
# ##### This means that there are a large number or subhurbs with almost no black people and there are a smaller number of subhurbs that have a disproportionately high amount of black people.

# %% [markdown]
# ### B_Series questions so far
# ##### How does this attribute relate to the other attributes?
# ##### Is there some iscolation present between black and white people?

# %% [markdown]
# ### Percentage of people with lower status (presumably this relates to wealth???)

# %%
plt.imshow(mpimg.imread('LSTAT_Series_visual_info.png'))

# %% [markdown]
# # Comments And Observations
# #### This count is a right-scewed Gaussan distribution.
# #### this is an indication as to how wealth is distributed with the minority of people that are wealthy and have high status.

# %% [markdown]
# # LSTAT_Series quesions so far
# ##### What relationships are there between this attribute and others?  Is there a way of grouping these attributes together in order to find out where all the rich people live?

# %% [markdown]
# # Creating pair plots for all attributes so that correlations can be identified quickly and easily for further investigation

# %%
sns.pairplot(Boston_DataFrame)
plt.show()

# %% [markdown]
# # Identification of all correlations and relationships between all pairs of attributes with observed distributions of subhurbs with the Charle's River running through them

# %%
CRIM_pair_plot_summary = {'Attribute Pair' : ['CRIM/ZN', 'CRIM/INDUS','CRIM/DIS', 'CRIM/AGE', 'CRIM/RAD', 'CRIM/TAX', 'CRIM/PTRATIO'], 'Correlation Or Other Pattern' : ['Either ZN or CRIM is 0', 'CRIM = 0 except when INDUS = 18','Strong exponential decay between DIS and CRIM','CRIM is high only when AGE is', 'RAD/CRIM same pattern as DIS/CRIM & TAX/CRIM', 'CRIM > 0 only when TAX = 666', 'PTRATIO has the same pattern as CRIM/TAX']}
CRIM_Comparison = pd.DataFrame(CRIM_pair_plot_summary)
CRIM_Comparison.index = CRIM_Comparison['Attribute Pair']
del CRIM_Comparison['Attribute Pair']

# %%
ZN_pair_plot_summary = {'Attribute Pair' : ['ZN/INDUS','ZN/NOX', 'ZN/B', 'ZN/LSTAT'], 'Correlation Or Other Pattern' : ['Weak exponential decay', 'Same pattern as ZN/INDUS', 'B varies as CHAS is low', 'Same pattern as B/CHAS']}
ZN_Comparison = pd.DataFrame(ZN_pair_plot_summary)
ZN_Comparison.index = ZN_Comparison['Attribute Pair']
del ZN_Comparison['Attribute Pair']

# %%
INDUS_pair_plot_summary = {'Attribute Pair' : ['INDUS/NOX', 'INDUS/RM', 'INDUS/AGE', 'INDUS/DIS', 'INDUS/TAX', 'INDUS/PTRATIO', 'INDUS/B', 'INDUS/LSTAT'], 'Correlation Or Other Pattern' : ['Moderate positive correlation', 'Weak negative correlation', 'Weak positive correlation', 'Exponential decay', 'Moderate positive correlation', 'Moderate/Weak correlation','B only low when INDUS = 8 or 18', 'Same as INDUS/AGE']}
INDUS_Comparison = pd.DataFrame(INDUS_pair_plot_summary)
INDUS_Comparison.index = INDUS_Comparison['Attribute Pair']
del INDUS_Comparison['Attribute Pair']

# %%
CHAS_pair_plot_summary = {'Attribute Pair' : ['CHAS/NOX','CHAS/RM', 'CHAS/AGE', 'CHAS/B','CHAS/LSTAT'], 'Correlation Or Other Pattern' : ['RM very low only when CHAS = 0', 'Same pattern as CHAS/RM', 'Same pattern as CHAS/RM & CHAS/NOX','B is high when CHAS = 1', 'highest LSTAT values only present when CHAS = 1']}
CHAS_Comparison = pd.DataFrame(CHAS_pair_plot_summary)
CHAS_Comparison.index = CHAS_Comparison['Attribute Pair']
del CHAS_Comparison['Attribute Pair']

# %%
NOX_pair_plot_summary = {'Attribute Pair' : ['NOX/RM', 'NOX/AGE', 'NOX/DIS', 'NOX/RAD', 'NOX/TAX', 'NOX/PTRATIO', 'NOX/LSTAT'], 'Correlation Or Other Pattern' : ['Weak negative correlation', 'Moderate positive correlation', 'Exponential decay', 'Positive Correlation & NOX varies with highest value', 'Same pattern as NOX/RAD', 'Same pattern as above two', 'Moderate positive correlation']}
NOX_Comparison = pd.DataFrame(NOX_pair_plot_summary)
NOX_Comparison.index = NOX_Comparison['Attribute Pair']
del NOX_Comparison['Attribute Pair']

# %%
RM_pair_plot_summary = {'Attribute Pair' : ['RM/AGE', 'RM/DIS', 'RM/LSTAT'], 'Correlation Or Other Pattern' : ['Strong negative correlation', 'Gaussian Distribution', 'Some third order decay']}
RM_Comparison = pd.DataFrame(RM_pair_plot_summary)
RM_Comparison.index = RM_Comparison['Attribute Pair']
del RM_Comparison['Attribute Pair']

# %%
AGE_pair_plot_summary = {'Attribute Pair' : ['AGE/DIS', 'AGE/LSTAT'], 'Correlation Or Other Pattern' : ['Negative correlation', 'Exponential growth']}
AGE_Comparison = pd.DataFrame(AGE_pair_plot_summary)
AGE_Comparison.index = AGE_Comparison['Attribute Pair']
del AGE_Comparison['Attribute Pair']

# %%
DIS_pair_plot_summary = {'Attribute Pair' : ['DIS/B', 'DIS/LSTAT'], 'Correlation Or Other Pattern' : ['DIS only increases when B is high enough', 'Exponential decay']}
DIS_Comparison = pd.DataFrame(DIS_pair_plot_summary)
DIS_Comparison.index = DIS_Comparison['Attribute Pair']
del DIS_Comparison['Attribute Pair']

# %%
RAD_pair_plot_summary = {'Attribute Pair' : ['RAD/TAX, PTRATIO, B, LSTAT'], 'Correlation Or Other Pattern' : ['No observed patterns']}
RAD_Comparison = pd.DataFrame(RAD_pair_plot_summary)
RAD_Comparison.index = RAD_Comparison['Attribute Pair']
del RAD_Comparison['Attribute Pair']

# %%
TAX_pair_plot_summary = {'Attribute Pair' : ['TAX/PTRATIO, B, LSTAT'], 'Correlation Or Other Pattern' : ['No observed patterns']}
TAX_Comparison = pd.DataFrame(TAX_pair_plot_summary)
TAX_Comparison.index = TAX_Comparison['Attribute Pair']
del TAX_Comparison['Attribute Pair']

# %%
PTRATIO_pair_plot_summary = {'Attribute Pair' : ['PTRATIO/LSTAT'], 'Correlation Or Other Pattern' : ['Weak positive correlation']}
PTRATIO_Comparison = pd.DataFrame(PTRATIO_pair_plot_summary)
PTRATIO_Comparison.index = PTRATIO_Comparison['Attribute Pair']
del PTRATIO_Comparison['Attribute Pair']

# %%
big_table = pd.concat([CRIM_Comparison, ZN_Comparison, INDUS_Comparison, CHAS_Comparison, NOX_Comparison, RM_Comparison, AGE_Comparison, DIS_Comparison, RAD_Comparison, PTRATIO_Comparison])
print(big_table)
dict_big_table = dict(big_table)
# Out:
#                                                  Correlation Or Other Pattern
# Attribute Pair
# CRIM/ZN                                                Either ZN or CRIM is 0
# CRIM/INDUS                                    CRIM = 0 except when INDUS = 18
# CRIM/DIS                        Strong exponential decay between DIS and CRIM
# CRIM/AGE                                        CRIM is high only when AGE is
# CRIM/RAD                         RAD/CRIM same pattern as DIS/CRIM & TAX/CRIM
# CRIM/TAX                                         CRIM > 0 only when TAX = 666
# CRIM/PTRATIO                         PTRATIO has the same pattern as CRIM/TAX
# ZN/INDUS                                               Weak exponential decay
# ZN/NOX                                               Same pattern as ZN/INDUS
# ZN/B                                                  B varies as CHAS is low
# ZN/LSTAT                                               Same pattern as B/CHAS
# ...

# %% [markdown]
# # Joint Plots with positive relationships

# %% [markdown]
# ### CRIM versus AGE

# %%
_= sns.jointplot(x = 'CRIM', y ='AGE', data = Boston_DataFrame)
_= sns.lmplot(x = 'CRIM', y = 'AGE', data = Boston_DataFrame, hue = 'CHAS', fit_reg = False)

# %% [markdown]
# ##### Only subhurbs that have a certain number or older houses have higher crime rates.
# ##### All new subhurbs have low crime rate.
# ##### Older subhurbs are closer to the river.

# %% [markdown]
# ### INDUS versus NOX, AGE, TAX and LSTAT

# %%
sns.jointplot (x = Boston_DataFrame['INDUS'], y = Boston_DataFrame['NOX']).annotate(stats.pearsonr)
sns.lmplot(x = 'INDUS', y = 'NOX', data = Boston_DataFrame, hue = 'CHAS', fit_reg = False)
sns.jointplot (x = Boston_DataFrame['INDUS'], y = Boston_DataFrame['AGE']).annotate(stats.pearsonr)
sns.lmplot(x = 'INDUS', y = 'AGE', data = Boston_DataFrame, hue = 'CHAS', fit_reg = False)
sns.jointplot (x = Boston_DataFrame['INDUS'], y = Boston_DataFrame['TAX']).annotate(stats.pearsonr)
sns.lmplot(x = 'INDUS', y = 'TAX', data = Boston_DataFrame, hue = 'CHAS', fit_reg = False)
sns.jointplot(x = Boston_DataFrame['INDUS'], y = Boston_DataFrame['LSTAT']).annotate(stats.pearsonr)
sns.lmplot(x = 'INDUS', y = 'LSTAT', data = Boston_DataFrame, hue = 'CHAS', fit_reg = False)
# Out:
# C:\Users\Matt\anaconda3\lib\site-packages\seaborn\axisgrid.py:1848: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))
# C:\Users\Matt\anaconda3\lib\site-packages\seaborn\axisgrid.py:1848: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))
# C:\Users\Matt\anaconda3\lib\site-packages\seaborn\axisgrid.py:1848: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))
# C:\Users\Matt\anaconda3\lib\site-packages\seaborn\axisgrid.py:1848: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# ##### Subhurbs in Boston with more non-retail business have higher NOX concentrations.
# ##### No newer subhurbs are highly occupied by non-retail businesses.
# ##### Subhurbs with non-retail business property have higher property taxes.
# ##### Higher socioeconomic status subhurbs have lower occupation of non-retail businesses.

# %% [markdown]
# ### NOX versus AGE, TAX, PTRATIO and LSTAT

# %%
sns.jointplot(x = Boston_DataFrame['NOX'], y = Boston_DataFrame['AGE']).annotate(stats.pearsonr)
sns.lmplot(x = 'NOX', y = 'AGE', data = Boston_DataFrame, hue = 'CHAS', fit_reg = False)
sns.jointplot(x = Boston_DataFrame['NOX'], y = Boston_DataFrame['TAX']).annotate(stats.pearsonr)
sns.lmplot(x = 'NOX', y = 'TAX', data = Boston_DataFrame, hue = 'CHAS', fit_reg = False)
sns.jointplot(x = Boston_DataFrame['NOX'], y = Boston_DataFrame['PTRATIO']).annotate(stats.pearsonr)
sns.lmplot(x = 'NOX', y = 'PTRATIO', data = Boston_DataFrame, hue = 'CHAS', fit_reg = False)
sns.jointplot(x = Boston_DataFrame['NOX'], y = Boston_DataFrame['LSTAT']).annotate(stats.pearsonr)
sns.lmplot(x = 'NOX', y = 'LSTAT', data = Boston_DataFrame, hue = 'CHAS', fit_reg = False)
# Out:
# C:\Users\Matt\anaconda3\lib\site-packages\seaborn\axisgrid.py:1848: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))
# C:\Users\Matt\anaconda3\lib\site-packages\seaborn\axisgrid.py:1848: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))
# C:\Users\Matt\anaconda3\lib\site-packages\seaborn\axisgrid.py:1848: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))
# C:\Users\Matt\anaconda3\lib\site-packages\seaborn\axisgrid.py:1848: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# ##### Older Subhurbs have higher NOX concentrations
# ##### The higher the NOX concentration the higher the property tax within that subhurb.
# ##### The higher the NOX concentration the higher the pupil/teacher ratio.  This is just a possible association.  Correlation here very weak
# ##### The higher the NOX concentration the poorer the subhurb.  This is also just a possible association.

# %% [markdown]
# ### AGE versus LSTAT

# %%
sns.jointplot(x = Boston_DataFrame['AGE'], y = Boston_DataFrame['LSTAT']).annotate(stats.pearsonr)
sns.lmplot(x = 'AGE', y = 'LSTAT', data = Boston_DataFrame, hue = 'CHAS', fit_reg = False)
# Out:
# C:\Users\Matt\anaconda3\lib\site-packages\seaborn\axisgrid.py:1848: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# ##### People who are high and low status/wealth live in both old and new homes.
# ##### Poor/low status people generally don't live in newer neighbourhoods.

# %%
sns.jointplot(x = Boston_DataFrame['PTRATIO'], y = Boston_DataFrame['LSTAT']).annotate(stats.pearsonr)
sns.lmplot(x = 'PTRATIO', y = 'LSTAT', data = Boston_DataFrame, hue = 'CHAS', fit_reg = False)
# Out:
# C:\Users\Matt\anaconda3\lib\site-packages\seaborn\axisgrid.py:1848: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# ##### Weak correlation showing that the higher the PTRATIO the lower the status/wealth of people living in that subhurb.

# %% [markdown]
# # Joint Plots with inverse relationships

# %% [markdown]
# # CRIM versus DIS

# %%
sns.jointplot(x = Boston_DataFrame['CRIM'], y = Boston_DataFrame['DIS']).annotate(stats.pearsonr)
sns.lmplot(x = 'CRIM', y = 'DIS', data = Boston_DataFrame, hue = 'CHAS', fit_reg = False)
# Out:
# C:\Users\Matt\anaconda3\lib\site-packages\seaborn\axisgrid.py:1848: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# ##### Very strong negative relationship between subhurbs distanced from employment centers and crime rate.
# ##### Areas where there are more employment centers have higher crime.

# %% [markdown]
# ### ZN versus INDUS and NOX

# %%
sns.jointplot(x = Boston_DataFrame['ZN'], y = Boston_DataFrame['INDUS']).annotate(stats.pearsonr)
sns.lmplot(x = 'ZN', y = 'INDUS', data = Boston_DataFrame, hue = 'CHAS', fit_reg = False)
sns.jointplot(x = Boston_DataFrame['ZN'], y = Boston_DataFrame['NOX']).annotate(stats.pearsonr)
sns.lmplot(x = 'ZN', y = 'NOX', data = Boston_DataFrame, hue = 'CHAS', fit_reg = False)
# Out:
# C:\Users\Matt\anaconda3\lib\site-packages\seaborn\axisgrid.py:1848: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))
# C:\Users\Matt\anaconda3\lib\site-packages\seaborn\axisgrid.py:1848: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# ##### For subhurbs where there is no land zoned for lots over 25000 sq feet, there is a large variation in the proportion of non-retail business acres.
# ##### As the proportion of land zoned for lots over 25000 sq feet increases, the proportion of non-retail businesses decreases.
# ##### Very same behavior with NOX concentrations over various proportions of land zoned for lots over 25000 sq feet.
# ##### This may be an indication that non-retail businesses like refineries and factories and other commercial businesses release NOX into the air.

# %% [markdown]
# ### INDUS versus RM and DIS

# %%
sns.jointplot(x = Boston_DataFrame['INDUS'], y = Boston_DataFrame['RM']).annotate(stats.pearsonr)
sns.lmplot(x = 'INDUS', y = 'RM', data = Boston_DataFrame, hue = 'CHAS', fit_reg = False)
sns.jointplot(x = Boston_DataFrame['INDUS'], y = Boston_DataFrame['DIS']).annotate(stats.pearsonr)
sns.lmplot(x = 'INDUS', y = 'DIS', data = Boston_DataFrame, hue = 'CHAS', fit_reg = False)
# Out:
# C:\Users\Matt\anaconda3\lib\site-packages\seaborn\axisgrid.py:1848: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))
# C:\Users\Matt\anaconda3\lib\site-packages\seaborn\axisgrid.py:1848: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# ##### The jointplot between RM and INDUS shows a weak negative correlation suggesting that areas with bigger houses have smaller non-retail businesses acres.
# ##### The more employment centers there are, the higher the number of non-retail busineses.

# %% [markdown]
# # NOX versus RM and DIS

# %%
sns.jointplot(x = Boston_DataFrame['NOX'], y = Boston_DataFrame['RM']).annotate(stats.pearsonr)
sns.lmplot(x = 'NOX', y = 'RM', data = Boston_DataFrame, hue = 'CHAS', fit_reg = False)
sns.jointplot(x = Boston_DataFrame['NOX'], y = Boston_DataFrame['DIS']).annotate(stats.pearsonr)
sns.lmplot(x = 'NOX', y = 'DIS', data = Boston_DataFrame, hue = 'CHAS', fit_reg = False)
# Out:
# C:\Users\Matt\anaconda3\lib\site-packages\seaborn\axisgrid.py:1848: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))
# C:\Users\Matt\anaconda3\lib\site-packages\seaborn\axisgrid.py:1848: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# ##### Weak correlation between RM and NOX in a simmilar way to RM vs INDUS suggesting that subhurbs with bigger houses have lower NOX values.  (Why are the correlations for these three attributes weak?)
# ##### Subhurbs with less employment centers have lower NOX concentrations.
# ##### The NOX/DIS jointplot shows a very strong relationship between NOX and weighted distances to five employment centers.
# ##### Maybe lot of the employment centers are situated in industrial areas where there is alot of pollution.

# %% [markdown]
# ### RM versus LSTAT

# %%
sns.jointplot(x = Boston_DataFrame['RM'], y = Boston_DataFrame['LSTAT']).annotate(stats.pearsonr)
sns.lmplot(x = 'RM', y = 'LSTAT', data = Boston_DataFrame, hue = 'CHAS', fit_reg = False)
# Out:
# C:\Users\Matt\anaconda3\lib\site-packages\seaborn\axisgrid.py:1848: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# ##### There is a strong negative correlation between LSTAT and RM, which makes sense since wealthier people have houses with more rooms.
# ##### If both RM and LSTAT were both symmetrically distributed, there would be a very strong negative correlation.
# ##### This is an indication of where all the wealthy people live.

# %% [markdown]
# ### AGE versus DIS

# %%
sns.jointplot(x = Boston_DataFrame['AGE'], y = Boston_DataFrame['DIS']).annotate(stats.pearsonr)
sns.lmplot(x = 'AGE', y = 'DIS', data = Boston_DataFrame, hue = 'CHAS', fit_reg = False)
# Out:
# C:\Users\Matt\anaconda3\lib\site-packages\seaborn\axisgrid.py:1848: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# ##### More employment centers are closer to older subhurbs and newer subhurbs are further away from employment centers.

# %% [markdown]
# ### DIS versus LSTAT

# %%
sns.jointplot(x = Boston_DataFrame['DIS'], y = Boston_DataFrame['LSTAT']).annotate(stats.pearsonr)
sns.lmplot(x = 'DIS', y = 'LSTAT', data = Boston_DataFrame, hue = 'CHAS', fit_reg = False)
# Out:
# C:\Users\Matt\anaconda3\lib\site-packages\seaborn\axisgrid.py:1848: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# ##### Weakly inverse relationship between status within a subhurb and it's proximity to employment centers.
# ##### Poorer people don't live far from employment centers because they can't.  Rich people have more freedom than that.

# %% [markdown]
# ### PTRATIO versus LSTAT

# %%
j = sns.jointplot(x = Boston_DataFrame['PTRATIO'], y = Boston_DataFrame['LSTAT']).annotate(stats.pearsonr)
sns.lmplot(x = 'PTRATIO', y = 'LSTAT', data = Boston_DataFrame, hue = 'CHAS', fit_reg = False)
# Out:
# C:\Users\Matt\anaconda3\lib\site-packages\seaborn\axisgrid.py:1848: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# ##### There are both rich and poor people that live near schools with larger classes but more of the wealthier people populate subhurbs near schools with smaller classes.

# %% [markdown]
# # Conclusions And Insights

# %% [markdown]
# ##### Subhurbs where there is a high proportion of non-retail business acres are also coupled with higher NOX levels in the air.  This indicates that non-retail businesses pollute the air with NOX emmisions.  But vehicles also emit NOX gasses into the air.  Downtown areas contain a high density of cars where alot of NOX gasses are releases by them.  Quite a few non-retail businesses are located downtown such as office buildings, commercial businesses and in some cases, industrial. All the datapoints that fit the criteria of downtown also indicate that this area of boston is older.  However there are other subhurbs that are higher in NOX values where there are alot of non-retail businesses like factories, powerplants and refineries.  The proportion of retail acres with both types of subhurbs are low.  These areas are undesirable to live in as well.  The downtown areas of boston all have high PTRATIOS, INDUS values and very low DIS values since downtown is very close to a few employment centers.  The downtown boston area also has very low if any acres of land zoned for lots over 25000 sq feet.   Property taxes are high downtown. and there is an equal distance from radial highways indicating their close proximity to one another.  Both rich and poor people live downtown, which consistent with the rich and the poor living in older subhurbs.  The rich people will live in pent houses, significantly raising the mean value of rooms per house, which ranges from 2 to about 5 or 6 rooms.
# ##### There is also more crime downtown.  There's a lot of crime downtown, which is consistent with how so many subhurbs with high crime rates are closer to employment centers.
# ##### Wealthier people live out in the newer subhurbs where there is a high proportion of land zoned for lots over 25000 sq feet and far away from non-retail businesses.  The newer subhurbs are where the wealthier people live as indicated by a higher average number of rooms per house and there is lower NOX concentrations.  These factors may indicate that there are the peripheral or outer areas of Boston where there are nicer houses, more schools with smaller classes and lower NOX emissions from a lack of non-retail businesses and heavy density of cars.
# ##### A lot of poorer people live in subhurbs that are closer to employment centers.
# ### Research/Hypothesis question:
# ##### How do the 13 variables determine the median house price of occupied houses within a subhurb.

# %%
plt.figure(figsize = (15, 15))
Boston_DataFrame.corr().abs()
z = Boston_DataFrame.corr().abs()
sns.heatmap(data=z, annot=True)

# %%
Identifying Independent Variable Pairs (corr coef is less than 0.5):
    CRIM; [ZN, INDUS, CHAS, NOX, RM, AGE, DIS, PTRATIO, B, LSTAT]
    ZN; [CHAS, RM, RAD, TAX, PTRATIO, B, LSTAT]
    INDUS; [CHAS, RM, PTRATIO, B]
    CHAS; [NOX, RM, AGE, DIS, RAD, TAX, PTRATIO, B, LSTAT]
    NOX; [RM, PTRATIO, B]
    RM; [AGE, DIS, RAD, TAX, PTRATIO, B, LSTAT]
    AGE; [RAD, PTRATIO, B]
    DIS; [RAD, PTRATIO, B]
    RAD; [PTRATIO, B, LSTAT]
    TAX; [PTRATIO, B]
    PTRATIO; [B, LSTAT]
    B; [LSTAT]
